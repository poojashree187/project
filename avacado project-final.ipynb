# %% [markdown]
# # Avacado Project

# %% [markdown]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

# %% [raw]
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## importing data

# %%
df = pd.read_csv('avocado.csv')

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
df['type'].unique()
# Out:
# array(['conventional', nan], dtype=object)

# %%
df['type'].isna().sum()
# Out:
# 14951

# %%
df.shape
# Out:
# (16468, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %% [markdown]
# ## EDA

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# almost 90 percent of nan values present in the dataset

# %%
 df=df.dropna()

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# Here we removed all the NaN valuse from the Data

# %%
df.shape
# Out:
# (1517, 14)

# %% [markdown]
# 1517 rows and 14 columns are present in the data

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# no null values present in the data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 177.8+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %% [markdown]
# all the above columns counts 1517 so there is no missing values present

# %% [markdown]
# ## Preprocessing

# %%
df.drop('Unnamed: 0',axis=1,inplace = True)

# %% [markdown]
# The above feature is just representation of index , so removing it

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %% [markdown]
# Unnamed 0 is successfully removed

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df["Date"].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %% [markdown]
# we are converting date to date type from object type

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# ...

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                   float64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %% [markdown]
# ### visualization

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm
fig, ax= plt.subplots(figsize=(15,9))
sns.distplot(a=df.AveragePrice, kde=False, fit=norm )

# %% [markdown]
# the avrerage price lies in the range of 1.1,1.4

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'Month', 'Day'],
#       dtype='object')

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids',
#        'GreatLakes', 'HarrisburgScranton', 'HartfordSpringfield',
#        'Houston', 'Indianapolis', 'Jacksonville', 'LasVegas',
#        'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Midsouth',
#        'Nashville', 'NewYork', 'Northeast', 'NorthernNewEngland',
#        'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains',
#        'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
regionlist=list(df.region.unique())
average_price=[]

for i in regionlist:
    x = df[df.region==i]
    region_average=sum(x.AveragePrice)/len(x)
    average_price.append(region_average)
df1=pd.DataFrame({'region_list':regionlist,'average_price':average_price})
new_index=df1.average_price.sort_values(ascending=False).index.values
sorted_data=df1.reindex(new_index)
plt.figure(figsize=(24,10))
ax=sns.barplot(x=sorted_data.region_list,y=sorted_data.average_price)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('average Price')
plt.title('Average Price of Avocodo to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocodo to Region')

# %% [markdown]
# the above graph shows in which region average price is high,Syracuse have highest average price

# %%
byDate=df.groupby('Date').mean()
plt.figure(figsize=(12,8))
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %%
byDate=df.groupby('Date').mean()
plt.figure(figsize=(12,8))
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %% [markdown]
# The above graph shows there is huge hike in the 2016-7 to 2017-01

# %%
corr_mat = df.corr()
corr_mat
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
# Month             0.060642     -0.055212 -0.053007 -0.058429 -0.055079
# Day               0.092589     -0.034857 -0.031806 -0.044008 -0.021318
#
# ...

# %%
plt.figure(figsize=[22,12])
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
plt.title('Correlatin matrix')
plt.show()

# %% [markdown]
# All the Features are not correlated with the Average Price Column, insted most of them are correlated with each other

# %%
df = df.drop(['region','Date'],axis=1)

# %% [markdown]
# i will drop date because we already have 3 other columns which tells date and i drop region because it have 54 unique values

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type    year  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015.0     12   27
# 1     9408.07       97.49          0.0  conventional  2015.0     12   20
# 2     8042.21      103.14          0.0  conventional  2015.0     12   13
# 3     5677.40      133.76          0.0  conventional  2015.0      6   12
# 4     5986.26      197.69          0.0  conventional  2015.0     11   29

# %%
sns.barplot(x="year",y="AveragePrice",data=df)

# %% [markdown]
# Average price is more in the year of 2016

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'Month',
#        'Day'],
#       dtype='object')

# %%
sns.barplot(x="Month",y="AveragePrice",data=df)

# %% [markdown]
# The average price is slightly more more in 10,11 and 2nd month

# %%
df.hist(figsize=(20,20),grid=True,layout=(4,3),bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C9E493670>,
# ...
#       dtype=object)

# %% [markdown]
# #here averageprice is normally distributed this is a goog sign that our model is correct choice for data

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# Month           0.101439
# Day             0.041303
# dtype: float64

# %% [markdown]
# skewness of columns is more than 0.5 so we have to treate skewness

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'Month',
#        'Day'],
#       dtype='object')

# %%
skew=( 'Total Volume', '4046', '4225', '4770', 'Total Bags',
       'Small Bags', 'Large Bags', 'XLarge Bags')

# %% [markdown]
# making separate coulm to treate skewness

# %%
for col in skew:
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# year            1.828332
# Month           0.101439
# Day             0.041303
# dtype: float64

# %% [markdown]
# skewness is successfully treated

# %%
df.plot(kind='box',subplots=True,layout=(4,3),figsize=(20,20))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Total Volume     AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# 4046             AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# 4225               AxesSubplot(0.125,0.518913;0.227941x0.16413)
# 4770            AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# Total Bags      AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# Small Bags         AxesSubplot(0.125,0.321957;0.227941x0.16413)
# Large Bags      AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# XLarge Bags     AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# year                  AxesSubplot(0.125,0.125;0.227941x0.16413)
# Month              AxesSubplot(0.398529,0.125;0.227941x0.16413)
# Day                AxesSubplot(0.672059,0.125;0.227941x0.16413)
# dtype: object

# %% [markdown]
# ouliers are present in some columns we will treate them

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# Month             int64
# Day               int64
# dtype: object

# %% [markdown]
# date is object type, so we convert it to integer type

# %%
df["type"]
# Out:
# 0       conventional
# 1       conventional
# 2       conventional
# 3       conventional
# 4       conventional
#             ...
# 1512    conventional
# 1513    conventional
# 1514    conventional
# 1515    conventional
# 1516    conventional
# Name: type, Length: 1517, dtype: object

# %%
df= pd.get_dummies(df)

# %%
df.shape
# Out:
# (1517, 13)

# %%
df.isna().sum()
# Out:
# AveragePrice         0
# Total Volume         0
# 4046                 0
# 4225                 0
# 4770                 0
# Total Bags           0
# Small Bags           0
# Large Bags           0
# XLarge Bags          0
# year                 0
# Month                0
# Day                  0
# type_conventional    0
# dtype: int64

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))
print(z)
# Out:
# [[1.35048079 1.35676174 1.82816171 ... 1.62415427 1.31052998        nan]
#  [1.45639674 1.46638736 2.01206913 ... 1.62415427 0.52953678        nan]
#  [0.76783831 0.9321394  1.94183376 ... 1.62415427 0.25145642        nan]
#  ...
#  [2.14485045 0.64565294 0.20190426 ... 1.25685839 0.58616779        nan]
#  [2.09189247 0.60503087 0.13577946 ... 0.75985047 1.08738906        nan]
#  [1.88006056 0.62805557 0.23299293 ... 0.75985047 0.30639586        nan]]

# %%
treshold = 3
print(np.where(z<3))
print(df.shape)
# Out:
# (array([   0,    0,    0, ..., 1516, 1516, 1516], dtype=int64), array([ 0,  1,  2, ...,  9, 10, 11], dtype=int64))
# (1517, 13)

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (0, 13)

# %% [markdown]
# if we treat the outliers it remove all the columns so we dropping this

# %% [markdown]
# #### splitting of data into x and y

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'year', 'Month', 'Day',
#        'type_conventional'],
#       dtype='object')

# %%
x = df.drop('AveragePrice',axis=1)
y = df['AveragePrice']

# %%
x.dtypes
# Out:
# Total Volume         float64
# 4046                 float64
# 4225                 float64
# 4770                 float64
# Total Bags           float64
# Small Bags           float64
# Large Bags           float64
# XLarge Bags          float64
# year                 float64
# Month                  int64
# Day                    int64
# type_conventional      uint8
# dtype: object

# %%
df.drop('type_conventional',axis=1,inplace= True)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %% [markdown]
# we are treating the data with standerd scaler

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),RandomForestRegressor(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(40,90):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=r_state)
    for i in model:
        i.fit(x_train,y_train)
        pre =i.predict(x_test)
        r2_sc = r2_score(y_test,pre)
        print("R2 score corresponding to random state",r_state,"is",r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            model = i
                

print()
print()
print()
print()
print()
print("max R2 score corresponding to random_state",final_state,"is",max_r2_score,"and model is",model)
# Out:
# R2 score corresponding to random state 40 is 0.5791863174363902
# R2 score corresponding to random state 40 is 0.3838778486967521
# R2 score corresponding to random state 40 is 0.6136645624839058
# R2 score corresponding to random state 40 is 0.35734275624470013
# R2 score corresponding to random state 40 is 0.7651454309374274
# R2 score corresponding to random state 40 is 0.7098447351363066
# R2 score corresponding to random state 41 is 0.6368921581674685
# R2 score corresponding to random state 41 is 0.608947919434407
# R2 score corresponding to random state 41 is 0.6177897188106264
# R2 score corresponding to random state 41 is 0.6273063326206474
# R2 score corresponding to random state 41 is 0.6099053484601424
# R2 score corresponding to random state 41 is 0.6373997109040028
# R2 score corresponding to random state 41 is 0.6149058964439533
# R2 score corresponding to random state 41 is 0.6425156117824807
# R2 score corresponding to random state 41 is 0.6290827671985179
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=40)
rf = RandomForestRegressor()
parameters={'max_features':['auto','sqrt','log2'],
            'criterion':['mse','mae']}
gcv=GridSearchCV(rf,parameters,cv=10)
gcv.fit(x,y)
gcv.best_params_
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf =RandomForestRegressor(max_features= 'sqrt', criterion = 'mse')
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
r2_sc = r2_score(y_test,pred)
print("R2 score :",r2_sc*100)
# Out:
# R2 score : 78.89965080070643

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,pred))
print('MSE:',metrics.mean_squared_error(y_test,pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.060953293413173605
# MSE: 0.006927873253493007
# RMSE: 0.08323384680220546

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('y_test')
plt.ylabel('prediction')
# Out:
# Text(0, 0.5, 'prediction')

# %% [markdown]
# here we see the straight line so we conclude from the above that it is fairly good model

# %% [markdown]
# ## saving the model

# %%
import joblib
joblib.dump(rf,'avacodorf.pkl')
# Out:
# ['avacodorf.pkl']

# %% [markdown]
# ## Loading the saved model

# %%
model = joblib.load('avacodorf.pkl')

# %%
prediction = model.predict(x_test)

# %%
print(r2_score(y_test,prediction)*100)
# Out:
# 78.89965080070643

# %%
prediction= pd.DataFrame(prediction)

# %%
prediction.to_csv('Result.csv')

# %%
prediction
# Out:
#           0
# 0    0.8557
# 1    1.2008
# 2    1.2978
# 3    0.6307
# 4    1.1097
# ..      ...
# 496  1.1742
# 497  1.0311
# 498  1.1829
# 499  1.3049
# 500  0.8930
#
# [501 rows x 1 columns]
