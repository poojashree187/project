# %% [markdown]
# # Temperature Forecast Project

# %% [markdown]
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.

# %% [markdown]
# ### Attribute Information:
#
# For more information, read [Cho et al, 2020].
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T

# %%
import pandas as pd

# %%
df= pd.read_csv("temperature.csv")

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# dataset have 7752 rows and 25 columns

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# date is the only feature which is object type  remaining are float type

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# most of the feature have null values

# %%
df['station'].value_counts()
# Out:
# 25.0    310
# 12.0    310
# 2.0     310
# 3.0     310
# 4.0     310
# 5.0     310
# 6.0     310
# 7.0     310
# 8.0     310
# 9.0     310
# 10.0    310
# 11.0    310
# 13.0    310
# 23.0    310
# 14.0    310
# 15.0    310
# 16.0    310
# 18.0    310
# 20.0    310
# 22.0    310
# 24.0    310
# 17.0    310
# 19.0    310
# 21.0    310
# 1.0     310
# Name: station, dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df["Date"].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)
df['Year'] = df["Date"].apply(lambda x:x.year)

# %% [markdown]
# extracting the feature into day,month and year columns

# %%
pd.set_option('display.max_columns',None)# makes to show all the columns

# %%
df.head(3)
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887  69.451805   0.233947
# 1         29.850689         24.035009  5.691890  51.937448   0.225508
# 2         30.091292         24.565633  6.138224  20.573050   0.209344
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0   0.203896   0.161697   0.130928         0.0         0.0         0.0
# 1   0.251771   0.159444   0.127727         0.0         0.0         0.0
# 2   0.257469   0.204091   0.142125         0.0         0.0         0.0
#
#    LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# ...

# %%
df['LDAPS_PPT2'].value_counts()
# Out:
# 0.000000     5151
# 0.001953        7
# 0.000040        3
# 0.000781        3
# 21.621661       2
#              ...
# 0.085236        1
# 0.041993        1
# 0.002633        1
# 0.039292        1
# 0.109433        1
# Name: LDAPS_PPT2, Length: 2510, dtype: int64

# %%
df.dropna(subset=['station','Date'],inplace= True)# droping the rows which have null values

# %%
df.isnull().sum()
# Out:
# station              0
# Date                 0
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# Month                0
# Day                  0
# Year                 0
# dtype: int64

# %%
import numpy as np

# %%
df.mean()
# Out:
# station               13.000000
# Present_Tmax          29.768464
# Present_Tmin          23.225742
# LDAPS_RHmin           56.758747
# LDAPS_RHmax           88.377125
# LDAPS_Tmax_lapse      29.613845
# LDAPS_Tmin_lapse      23.512997
# LDAPS_WS               7.096501
# LDAPS_LH              62.495273
# LDAPS_CC1              0.368744
# LDAPS_CC2              0.356047
# LDAPS_CC3              0.318359
# LDAPS_CC4              0.299142
# LDAPS_PPT1             0.589061
# LDAPS_PPT2             0.482312
# LDAPS_PPT3             0.276208
# LDAPS_PPT4             0.267307
# lat                   37.544720
# lon                  126.991400
# DEM                   61.854944
# Slope                  1.256692
# Solar radiation     5341.549330
# Next_Tmax             30.275437
# Next_Tmin             22.932837
# Month                  7.080645
# Day                   16.370968
# Year                2015.000000
# dtype: float64

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# Month                      float64
# Day                        float64
# ...

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Month               0
# Day                 0
# Year                0
# dtype: int64

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# Month                      float64
# Day                        float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
byDate=df.groupby('Month').mean()
plt.figure(figsize=(20,8))
byDate['Next_Tmax'].plot()
plt.title('Next_Tmax')
# Out:
# Text(0.5, 1.0, 'Next_Tmax')

# %% [markdown]
# The maximum air temperature present in the 10-11 month

# %%
byDate=df.groupby('Month').mean()
plt.figure(figsize=(20,8))
byDate['Present_Tmin'].plot()
plt.title('Present_Tmix')
# Out:
# Text(0.5, 1.0, 'Present_Tmix')

# %% [markdown]
# minimum air temperature present in 6 anda 8yh month

# %%
byDate=df.groupby('Year').mean()
plt.figure(figsize=(20,8))
byDate['Next_Tmax'].plot()
plt.title('Next_Tmax')
# Out:
# Text(0.5, 1.0, 'Next_Tmax')

# %% [markdown]
# maximum air temperature present in the year 2016

# %%
byDate=df.groupby('Year').mean()
plt.figure(figsize=(20,8))
byDate['Next_Tmin'].plot()
plt.title('Next_Tmin')
# Out:
# Text(0.5, 1.0, 'Next_Tmin')

# %% [markdown]
# minimum air temperature present in teh year 2014

# %%
import seaborn as sns

# %%
plt.figure(figsize=[22,12])
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
plt.title('correlation matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
corr_matrix = df.corr()
corr_matrix["Next_Tmax"].sort_values(ascending = False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.826630
# Next_Tmin           0.620119
# Present_Tmax        0.609320
# LDAPS_Tmin_lapse    0.585728
# Present_Tmin        0.469903
# LDAPS_LH            0.155305
# station             0.108154
# Year                0.060091
# Solar radiation     0.007014
# lon                 0.001303
# Month              -0.026865
# lat                -0.055268
# Slope              -0.104421
# Day                -0.116902
# LDAPS_PPT1         -0.124598
# DEM                -0.174384
# LDAPS_PPT2         -0.184874
# LDAPS_PPT4         -0.186269
# LDAPS_PPT3         -0.201779
# LDAPS_RHmax        -0.287320
# LDAPS_WS           -0.347861
# LDAPS_RHmin        -0.441382
# LDAPS_CC4          -0.448861
# LDAPS_CC1          -0.455046
# LDAPS_CC2          -0.493371
# LDAPS_CC3          -0.517429
# Name: Next_Tmax, dtype: float64

# %%
corr_matrix = df.corr()
corr_matrix["Next_Tmin"].sort_values(ascending = False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.879809
# Present_Tmin        0.795860
# Present_Tmax        0.621706
# Next_Tmax           0.620119
# LDAPS_Tmax_lapse    0.585411
# station             0.128539
# Solar radiation     0.118531
# LDAPS_RHmin         0.092732
# LDAPS_CC2           0.029632
# Year                0.023181
# LDAPS_PPT1          0.017057
# LDAPS_PPT2         -0.012680
# LDAPS_CC1          -0.012730
# Month              -0.024470
# lon                -0.048623
# LDAPS_CC3          -0.056592
# LDAPS_LH           -0.058624
# LDAPS_PPT3         -0.068521
# LDAPS_RHmax        -0.075298
# lat                -0.085509
# LDAPS_CC4          -0.086975
# LDAPS_WS           -0.100693
# LDAPS_PPT4         -0.110245
# Day                -0.129587
# Slope              -0.148784
# DEM                -0.249059
# Name: Next_Tmin, dtype: float64

# %%
sns.barplot(x='Month',y='Next_Tmax',data = df)

# %%
sns.barplot(x='Month',y='Next_Tmin',data = df)

# %%
plt.hist(df['Next_Tmin'], bins = 20, color ='red')
plt.title('Target Variable')
plt.xlabel('Next_Tmin')
plt.ylabel('count')
plt.show()

# %%
plt.hist(df['Next_Tmax'], bins = 20, color ='red')
plt.title('Target Variable')
plt.xlabel('Next_Tmax')
plt.ylabel('count')
plt.show()

# %%
df.hist(figsize=(20,30),grid=True,layout=(9,3),bins=20);

# %% [markdown]
# Next_Tmax,Next_Tmin are noramally distributed in the above graph

# %%
byDate=df.groupby('Month').mean()
plt.figure(figsize=(20,8))
byDate['Solar radiation'].plot()
plt.title('Solar radiation')
# Out:
# Text(0.5, 1.0, 'Solar radiation')

# %% [markdown]
# solar radiation is less in the month of 8

# %%
df.plot(kind='box',subplots=True,layout=(9,3),figsize=(20,20));

# %%
plt.figure(figsize=(22,7))
df.corr()['Next_Tmin'].sort_values(ascending=False).drop('Next_Tmin').plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize=30)
plt.ylabel('column with target names',fontsize=20)
plt.title('correlation',fontsize=30)
plt.show()

# %% [markdown]
# minimum air temperature is more correlated with LDAPS_Tmin_lapse and less correlated with LDAPS_PPT1 and LDAPS_ccc1

# %%
plt.figure(figsize=(22,7))
df.corr()['Next_Tmax'].sort_values(ascending=False).drop('Next_Tmax').plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize=30)
plt.ylabel('column with target names',fontsize=20)
plt.title('correlation',fontsize=30)
plt.show()

# %% [markdown]
# Maximum air temperature is more correlated with LDAPS_Tmax_lapse and less correlated with ion

# %%
df.isna().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Month               0
# Day                 0
# Year                0
# dtype: int64

# %%
sns.distplot(df['Present_Tmax'],kde=True)

# %%
sns.distplot(df['Present_Tmin'],kde=True)

# %%
sns.distplot(df['LDAPS_RHmin'],kde=True)

# %%
sns.distplot(df['LDAPS_RHmax'],kde=True)

# %%
sns.distplot(df['LDAPS_Tmax_lapse'],kde=True)

# %%
sns.distplot(df['LDAPS_Tmin_lapse'],kde=True)

# %%
sns.distplot(df['LDAPS_WS'],kde=True)

# %%
sns.distplot(df['LDAPS_LH'],kde=True)

# %%
sns.distplot(df['LDAPS_CC1'],kde=True)

# %%
sns.distplot(df['LDAPS_PPT1'],kde=True)

# %%
sns.distplot(df['lat'],kde=True)

# %%
sns.distplot(df['Slope'],kde=True)

# %%
sns.distplot(df['Solar radiation'],kde=True)

# %%
sns.distplot(df['Next_Tmax'],kde=True)

# %%
sns.distplot(df['Next_Tmin'],kde=True)

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7750.000000   7750.000000  7750.000000  7750.000000
# mean     13.000000     29.768464     23.225742    56.758747    88.377125
# std       7.211568      2.953516      2.398327    14.585101     7.149011
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.048225    84.318649
# 50%      13.000000     29.900000     23.400000    55.313244    89.699505
# 75%      19.000000     32.000000     24.875000    67.032715    93.703491
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7750.000000       7750.000000  7750.000000  7750.000000
# mean          29.613845         23.512997     7.096501    62.495273
# std            2.928357          2.330881     2.166519    33.516382
# ...

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.263016
# Present_Tmin       -0.357573
# LDAPS_RHmin         0.300230
# LDAPS_RHmax        -0.850666
# LDAPS_Tmax_lapse   -0.224211
# LDAPS_Tmin_lapse   -0.579038
# LDAPS_WS            1.556441
# LDAPS_LH            0.667591
# LDAPS_CC1           0.459196
# LDAPS_CC2           0.471968
# LDAPS_CC3           0.640094
# LDAPS_CC4           0.665834
# LDAPS_PPT1          5.324449
# LDAPS_PPT2          5.713292
# LDAPS_PPT3          6.368744
# LDAPS_PPT4          6.743282
# lat                 0.086942
# lon                -0.285300
# DEM                 1.723944
# Slope               1.563346
# Solar radiation    -0.511006
# Next_Tmax          -0.335958
# Next_Tmin          -0.396876
# Month              -0.705241
# Day                 0.245482
# Year                0.000000
# dtype: float64

# %% [markdown]
# ## outliers check

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# Month                      float64
# Day                        float64
# ...

# %%
x = df.drop(columns =['Next_Tmax','Next_Tmin'],axis =1)

# %%
x.iloc[:,:9].boxplot(figsize=[20,5])
plt.subplots_adjust(bottom=0.2500)
plt.show()

# %%
x.iloc[:,:27].boxplot(figsize=[20,5])
plt.subplots_adjust(bottom=0.2500)
plt.show()

# %%
df.drop('Date',axis=1, inplace = True)

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
new_df = df[(z<3).all(axis = 1)]

# %%
df.shape
# Out:
# (7750, 27)

# %%
new_df.shape
# Out:
# (6888, 27)

# %%
((7750-6888)/7750)*100
# Out:
# 11.122580645161289

# %% [markdown]
# 11 percent of data will loss so we are not removing the outliers

# %%
df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Month', 'Day', 'Year'],
#       dtype='object')

# %%
skew=['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
       'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
       'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
       'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
       'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Month', 'Day', 'Year']

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for col in skew:#handelling the skewness
    if df.skew().loc[col]>0.55:
        df[col] = np.cbrt(df[col])

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.263016
# Present_Tmin       -0.357573
# LDAPS_RHmin         0.300230
# LDAPS_RHmax        -0.850666
# LDAPS_Tmax_lapse   -0.224211
# LDAPS_Tmin_lapse   -0.579038
# LDAPS_WS            0.877670
# LDAPS_LH           -0.352349
# LDAPS_CC1           0.459196
# LDAPS_CC2           0.471968
# LDAPS_CC3          -0.569758
# LDAPS_CC4          -0.466386
# LDAPS_PPT1          1.918915
# LDAPS_PPT2          2.219123
# LDAPS_PPT3          2.518089
# LDAPS_PPT4          2.786327
# lat                 0.086942
# lon                -0.285300
# DEM                 0.920075
# Slope               0.614133
# Solar radiation    -0.511006
# Next_Tmax          -0.335958
# Next_Tmin          -0.396876
# Month              -0.705241
# Day                 0.245482
# Year                0.000000
# dtype: float64

# %% [markdown]
# ### splitting of data into target and feature

# %%
x = df.drop(columns =['Next_Tmax','Next_Tmin'],axis =1)

# %%
y1 = df['Next_Tmax']

# %%
y2 = df['Next_Tmin']

# %%
from sklearn.preprocessing import StandardScaler# scaling the data using the standerd scaler
sc=StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
x.isna().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Month               0
# Day                 0
# Year                0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y1,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i},the training accuracy is: {r2_score(y_train,pred_train)}")
    print(f"At random state{i},the training accuracy is: {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state1,the training accuracy is: 0.7589786658939464
# At random state1,the training accuracy is: 0.775985566676446
#
#
# At random state2,the training accuracy is: 0.7644781181872609
# At random state2,the training accuracy is: 0.753029979220776
#
#
# At random state3,the training accuracy is: 0.7623975571235648
# At random state3,the training accuracy is: 0.7612885600271547
#
#
# At random state4,the training accuracy is: 0.760554848504651
# At random state4,the training accuracy is: 0.7682586039394587
#
#
# At random state5,the training accuracy is: 0.7624901722494646
# At random state5,the training accuracy is: 0.7612812282271544
#
#
# At random state6,the training accuracy is: 0.7663415006262657
# At random state6,the training accuracy is: 0.744969564569431
#
#
# At random state7,the training accuracy is: 0.7637304180485972
# At random state7,the training accuracy is: 0.7560177479524919
#
#
# At random state8,the training accuracy is: 0.7700981742057651
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y1,test_size=.20,random_state=16)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.7628181070702621

# %% [markdown]
# ## Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(1,10))}
ls = Lasso()
gcv=GridSearchCV(ls,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 1}

# %%
ls = Lasso(alpha= 0.0001, random_state = 1)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred = ls.predict(x_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# r2score is 0.7628221128140603

# %%
scr = cross_val_score(ls,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.6691443821744585

# %%
from sklearn.ensemble import RandomForestRegressor
parameters ={'max_features':['auto','sqrt','log2'],
            'criterion':['mse','mae']}
rf = RandomForestRegressor()
gcv=GridSearchCV(rf,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf =RandomForestRegressor(max_features= 'auto', criterion = 'mse')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred = rf.predict(x_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# r2score is 0.9116678978589123

# %%
scr = cross_val_score(rf,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.682785477437197

# %%
from sklearn.tree import DecisionTreeRegressor
parameters ={'max_features':['auto','sqrt','log2'],
            'criterion':['mse','mae']}
dt = DecisionTreeRegressor()
gcv=GridSearchCV(dt,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
dt =DecisionTreeRegressor(max_features= 'auto', criterion = 'mse')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
predt = dt.predict(x_test)
r=r2_score(y_test,predt)
print('r2score is',r)
# Out:
# r2score is 0.788842499817979

# %%
scr = cross_val_score(dt,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.43024237272996435

# %%
from sklearn.neighbors import KNeighborsRegressor
parameters ={'n_neighbors':[2,3,4,5,6,7,8]}
kn = KNeighborsRegressor()
gcv=GridSearchCV(kn,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'n_neighbors': 6}

# %%
kn =KNeighborsRegressor(n_neighbors = 6)
kn.fit(x_train,y_train)
kn.score(x_train,y_train)
predtk = kn.predict(x_test)
r=r2_score(y_test,predtk)
print('r2score is',r)
# Out:
# r2score is 0.6729429011466908

# %%
scr = cross_val_score(kn,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.24812168421600692

# %%
parameters ={'n_estimators':[50,100],
            'learning_rate':[.01,.05,.1,.3,1]}
ad = AdaBoostRegressor()
gcv=GridSearchCV(ad,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'learning_rate': 1, 'n_estimators': 100}

# %%
ad =AdaBoostRegressor(n_estimators = 6,learning_rate=1)
ad.fit(x_train,y_train)
ad.score(x_train,y_train)
predta = ad.predict(x_test)
r=r2_score(y_test,predta)
print('r2score is',r)
# Out:
# r2score is 0.7207017524086718

# %%
scr = cross_val_score(ad,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.6349967546756231

# %% [markdown]
# RandomForestClassifier is giving the best result

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,pred))
print('MSE:',metrics.mean_squared_error(y_test,pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.6720247784372614
# MSE: 0.8366715771801058
# RMSE: 0.9146975331660766

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('y_test')
plt.ylabel('prediction')
# Out:
# Text(0, 0.5, 'prediction')

# %% [markdown]
# here we see the straight line so we conclude from the above that it is fairly good model

# %% [markdown]
# ## saving the model

# %%
import joblib
joblib.dump(rf,'maxrf.pkl')
# Out:
# ['maxrf.pkl']

# %% [markdown]
# ## Loading the saved model

# %%
model = joblib.load('maxrf.pkl')

# %%
prediction = model.predict(x_test)

# %%
print(r2_score(y_test,prediction)*100)
# Out:
# 91.16678978589124

# %%
prediction= pd.DataFrame(prediction)

# %%
prediction.to_csv('Result.csv')

# %%
prediction
# Out:
#               0
# 0     28.778000
# 1     31.339000
# 2     33.117000
# 3     30.768000
# 4     33.918000
# ...         ...
# 1545  33.182263
# 1546  31.055000
# 1547  26.799754
# 1548  31.037754
# 1549  35.510000
#
# [1550 rows x 1 columns]

# %% [markdown]
# # for target Next_Tmin

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns =['Next_Tmax','Next_Tmin'],axis =1)

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y2,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i},the training accuracy is: {r2_score(y_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is: {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state1,the training accuracy is: 0.8283810774237994
# At random state1,the testing accuracy is: 0.8342678244970758
#
#
# At random state2,the training accuracy is: 0.8300583373563452
# At random state2,the testing accuracy is: 0.8270487480652124
#
#
# At random state3,the training accuracy is: 0.8260279522415948
# At random state3,the testing accuracy is: 0.8424594201461105
#
#
# At random state4,the training accuracy is: 0.828967245520492
# At random state4,the testing accuracy is: 0.8311930332545989
#
#
# At random state5,the training accuracy is: 0.8282745895692394
# At random state5,the testing accuracy is: 0.8343478440225562
#
#
# At random state6,the training accuracy is: 0.8317577646759586
# At random state6,the testing accuracy is: 0.8201570144617337
#
#
# At random state7,the training accuracy is: 0.8280565119569778
# At random state7,the testing accuracy is: 0.8349490113121706
#
#
# At random state8,the training accuracy is: 0.8315002333907553
# ...

# %%
kn =KNeighborsRegressor(n_neighbors = 6)
kn.fit(x_train,y_train)
kn.score(x_train,y_train)
predtk = kn.predict(x_test)
r=r2_score(y_test,predtk)
print('r2score is',r)
# Out:
# r2score is 0.6898996627810685

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y1,test_size=.20,random_state=14)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.7690389317859623

# %% [markdown]
# ## Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(1,10))}
ls = Lasso()
gcv=GridSearchCV(ls,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 1}

# %%
ls = Lasso(alpha= 0.0001, random_state = 1)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred = ls.predict(x_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# r2score is 0.7690757141065765

# %%
scr = cross_val_score(ls,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.6691443821744585

# %%
from sklearn.ensemble import RandomForestRegressor
parameters ={'max_features':['auto','sqrt','log2'],
            'criterion':['mse','mae']}
rf = RandomForestRegressor()
gcv=GridSearchCV(rf,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf =RandomForestRegressor(max_features= 'sqrt', criterion = 'mse')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred = rf.predict(x_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# r2score is 0.9243692437998582

# %%
scr = cross_val_score(rf,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.6772033620562958

# %%
from sklearn.tree import DecisionTreeRegressor
parameters ={'max_features':['auto','sqrt','log2'],
            'criterion':['mse','mae']}
dt = DecisionTreeRegressor()
gcv=GridSearchCV(dt,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
dt =DecisionTreeRegressor(max_features= 'auto', criterion = 'mse')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
predt = dt.predict(x_test)
r=r2_score(y_test,predt)
print('r2score is',r)
# Out:
# r2score is 0.7987013551245017

# %%
scr = cross_val_score(dt,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.4457709464262186

# %%
from sklearn.neighbors import KNeighborsRegressor
parameters ={'n_neighbors':[2,3,4,5,6,7,8]}
kn = KNeighborsRegressor()
gcv=GridSearchCV(kn,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'n_neighbors': 5}

# %%
kn =KNeighborsRegressor(n_neighbors = 5)
kn.fit(x_train,y_train)
kn.score(x_train,y_train)
predtk = kn.predict(x_test)
r=r2_score(y_test,predtk)
print('r2score is',r)
# Out:
# r2score is 0.6635136488083733

# %%
scr = cross_val_score(kn,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.24261418954716704

# %%
parameters ={'n_estimators':[50,100],
            'learning_rate':[.01,.05,.1,.3,1]}
ad = AdaBoostRegressor()
gcv=GridSearchCV(ad,parameters)
gcv.fit(x_train,y_train)
print(gcv.best_params_)
# Out:
# {'learning_rate': 1, 'n_estimators': 100}

# %%
ad =AdaBoostRegressor(n_estimators = 1,learning_rate=100)
ad.fit(x_train,y_train)
ad.score(x_train,y_train)
predta = ad.predict(x_test)
r=r2_score(y_test,predta)
print('r2score is',r)
# Out:
# r2score is 0.6816465174968225

# %%
scr = cross_val_score(ad,x,y1,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.5980736666765821

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,pred))
print('MSE:',metrics.mean_squared_error(y_test,pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.6482725221270361
# MSE: 0.7450827225084424
# RMSE: 0.8631817436139636

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('y_test')
plt.ylabel('prediction')
# Out:
# Text(0, 0.5, 'prediction')

# %% [markdown]
# here we see the straight line so we conclude from the above that it is fairly good model

# %% [markdown]
# ## saving the model

# %%
import joblib
joblib.dump(rf,'minrf.pkl')
# Out:
# ['minrf.pkl']

# %% [markdown]
# ## Loading the saved model

# %%
model = joblib.load('minrf.pkl')

# %%
prediction = model.predict(x_test)

# %%
print(r2_score(y_test,prediction)*100)
# Out:
# 92.43692437998583

# %%
prediction= pd.DataFrame(prediction)

# %%
prediction.to_csv('Result.csv')

# %%
prediction
# Out:
#               0
# 0     32.584000
# 1     31.625000
# 2     31.700000
# 3     29.578754
# 4     31.931000
# ...         ...
# 1545  27.548000
# 1546  31.768000
# 1547  30.732000
# 1548  31.874000
# 1549  26.927000
#
# [1550 rows x 1 columns]

# %% [markdown]
# # Conclusion

# %% [raw]
# # Conclusion
# --> The aim of the project is to predict the bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model
# --> The project have two target values Next_Tmax and Next_Tmin
# --> In EDA we remove all the null values present and replace them with the mean and mode of the column
# --> using the vizualization we are able to conclude the relation between the data
# -->finally able to build the model and cross validate it and hyper tunned the model
# -->and lastly saved the model in joblib
# -->we done this for two different targets
