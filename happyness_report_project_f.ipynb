# %% [markdown]
# ## World Happiness Report
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('world_happiness_report.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# data contain 158 rows and 12 columns

# %%
 df =df.drop(columns=['Region','Happiness Rank'])

# %%
df.head()
# Out:
#        Country  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0  Switzerland            7.587         0.03411                   1.39651
# 1      Iceland            7.561         0.04884                   1.30232
# 2      Denmark            7.527         0.03328                   1.32548
# 3       Norway            7.522         0.03880                   1.45900
# 4       Canada            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
 df.set_index('Country', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, Switzerland to Togo
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Score                158 non-null    float64
#  1   Standard Error                 158 non-null    float64
#  2   Economy (GDP per Capita)       158 non-null    float64
#  3   Family                         158 non-null    float64
#  4   Health (Life Expectancy)       158 non-null    float64
#  5   Freedom                        158 non-null    float64
#  6   Trust (Government Corruption)  158 non-null    float64
#  7   Generosity                     158 non-null    float64
#  8   Dystopia Residual              158 non-null    float64
# dtypes: float64(9)
# memory usage: 12.3+ KB

# %%
df.dtypes
# Out:
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df. isnull().sum()
# Out:
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.boxplot(figsize=[20,5])

# %%
df.iloc[:,3:].boxplot(figsize=[20,5])
plt.subplots_adjust(bottom=0.2500)
plt.show()

# %%
df.plot(kind='density',subplots = True,layout=(6,11),figsize =[22,12],sharex = False,legend = False)
plt.show()

# %%
sns.pairplot(df)# example of multivarient analysis
plt.show()

# %%
plt.figure(figsize=[15,5])
sns.heatmap(df.isnull())
plt.title('NULL VALUES')
plt.show()

# %% [markdown]
# there is no null values in the dataset

# %% [markdown]
# ### checking correlation

# %%
corr_mat = df.corr()

# %%
corr_mat
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
plt.figure(figsize=[22,12])
sns.heatmap(corr_mat,annot = True)
plt.title('Correlatin matrix')
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix["Happiness Score"].sort_values(ascending = False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Name: Happiness Score, dtype: float64

# %% [markdown]
# now we can clearly identify the corrletion of independent variable with target variable Happiness score .

# %% [markdown]
# ## lets check the data distribution among all the columns

# %%
# this is an onother example of multivarient analysis
df.plot(kind='density',subplots = True,layout=(6,11),figsize =[22,12],sharex = False,legend = False)
plt.show()

# %%
df.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
columns =['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
       'Family', 'Health (Life Expectancy)', 'Freedom',
       'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
for i in df[columns]:
    plt.figure()
    sns.distplot(df[i])

# %%
df.boxplot(figsize=[20,5])
plt.subplots_adjust(bottom=0.2500)
plt.show()

# %%
df.iloc[:,1:].boxplot(figsize=[20,5])
plt.subplots_adjust(bottom=0.2500)
plt.show()

# %%
x = df.drop('Happiness Score',axis =1)
y = df['Happiness Score']

# %%
# checking the skewness
x.skew()
# Out:
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# we can see the skewness in dataset. we will remove the skewness using power transform function

# %%
from sklearn.preprocessing import power_transform
df_new = power_transform(x)

df_new =pd.DataFrame(df_new,columns=x.columns)

# %%
df_new.skew()
# Out:
# Standard Error                  -0.020092
# Economy (GDP per Capita)        -0.127233
# Family                          -0.169651
# Health (Life Expectancy)        -0.183181
# Freedom                         -0.080728
# Trust (Government Corruption)    0.185965
# Generosity                       0.013320
# Dystopia Residual                0.022925
# dtype: float64

# %%
columns =['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
       'Family', 'Health (Life Expectancy)', 'Freedom',
       'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
for i in df[columns]:
    plt.figure()
    sns.distplot(df[i])

# %%
sns.boxplot(df['Standard Error'])

# %%
from scipy.stats import zscore
zscr = np.abs(zscore(df))
threshold=3
print(np.where(zscr>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
df
# Out:
#              Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Country
# Switzerland            7.587         0.03411                   1.39651
# Iceland                7.561         0.04884                   1.30232
# Denmark                7.527         0.03328                   1.32548
# Norway                 7.522         0.03880                   1.45900
# Canada                 7.427         0.03553                   1.32629
# ...                      ...             ...                       ...
# Rwanda                 3.465         0.03464                   0.22208
# Benin                  3.340         0.03656                   0.28665
# Syria                  3.006         0.05015                   0.66320
# Burundi                2.905         0.08658                   0.01530
# Togo                   2.839         0.06727                   0.20868
#
#               Family  Health (Life Expectancy)  Freedom  \
# Country
# ...

# %%
sns.boxplot(df['Standard Error'])

# %%
#lets check the presence of outliers
print('shape before removing the outliers :',df.shape)

dsnew =df [(zscr<3).all(axis=1)]

print('shape after removing the outliers :',df_new.shape)
# Out:
# shape before removing the outliers : (158, 9)
# shape after removing the outliers : (158, 8)

# %%
df_new.shape
# Out:
# (158, 8)

# %%
(1/8)*100
# Out:
# 12.5

# %% [markdown]
# it is more than 10 percent so we are dropping this

# %%
 x = df.drop('Happiness Score',axis = 1)

# %%
y = df['Happiness Score']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=43)

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_train,y_train)
# Out:
# 0.9999999425871688

# %%
lm.coef_
# Out:
# array([4.69583504e-04, 1.00005158e+00, 9.99898718e-01, 9.99982613e-01,
#        9.99757496e-01, 9.99718353e-01, 1.00010945e+00, 1.00001530e+00])

# %%
pred=lm.predict(x_test)
print('predicted result price:',pred)
print('actual price',y_test)
# Out:
# predicted result price: [5.12315392 4.83928341 3.65506999 7.58680933 5.21192954 5.60460297
#  3.8450203  5.28638715 6.90126507 6.29815756 7.27769421 4.29669344
#  4.88452614 5.19229388 4.69404116 7.52691577 7.22571587 4.60970934
#  6.98253327 7.19979367 5.19380586 4.95941618 5.26796149 4.07677676
#  6.26927959 3.81932448 7.56087135 6.50507923 5.75440249 4.63351322
#  5.88975779 4.78646202 6.94018468 2.83903981 4.85759175 5.69532129
#  6.29471312 4.29256215 5.98704707 5.82413826 5.68879146 5.47378749
#  7.28394618 5.54808326 5.42854557 5.82829728 4.41933524 3.90377785]
# actual price Country
# Serbia                  5.123
# Lebanon                 4.839
# Ivory Coast             3.655
# Switzerland             7.587
# Azerbaijan              5.212
# Algeria                 5.605
# Niger                   3.845
# Kyrgyzstan              5.286
# United Arab Emirates    6.901
# Taiwan                  6.298
# Israel                  7.278
# Georgia                 4.297
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)
# Out:
# 0.9999999358808007

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
pred=lm.predict(x_test)
print('predicted result price:',pred)
print('actual price',y_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# predicted result price: [5.12315392 4.83928341 3.65506999 7.58680933 5.21192954 5.60460297
#  3.8450203  5.28638715 6.90126507 6.29815756 7.27769421 4.29669344
#  4.88452614 5.19229388 4.69404116 7.52691577 7.22571587 4.60970934
#  6.98253327 7.19979367 5.19380586 4.95941618 5.26796149 4.07677676
#  6.26927959 3.81932448 7.56087135 6.50507923 5.75440249 4.63351322
#  5.88975779 4.78646202 6.94018468 2.83903981 4.85759175 5.69532129
#  6.29471312 4.29256215 5.98704707 5.82413826 5.68879146 5.47378749
#  7.28394618 5.54808326 5.42854557 5.82829728 4.41933524 3.90377785]
# actual price Country
# Serbia                  5.123
# Lebanon                 4.839
# Ivory Coast             3.655
# Switzerland             7.587
# Azerbaijan              5.212
# Algeria                 5.605
# Niger                   3.845
# Kyrgyzstan              5.286
# United Arab Emirates    6.901
# Taiwan                  6.298
# Israel                  7.278
# Georgia                 4.297
# ...

# %%
from sklearn.svm import SVR
sr=SVR()
dt.fit(x_train,y_train)
pred=lm.predict(x_test)
print('predicted result price:',pred)
print('actual price',y_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# predicted result price: [5.12315392 4.83928341 3.65506999 7.58680933 5.21192954 5.60460297
#  3.8450203  5.28638715 6.90126507 6.29815756 7.27769421 4.29669344
#  4.88452614 5.19229388 4.69404116 7.52691577 7.22571587 4.60970934
#  6.98253327 7.19979367 5.19380586 4.95941618 5.26796149 4.07677676
#  6.26927959 3.81932448 7.56087135 6.50507923 5.75440249 4.63351322
#  5.88975779 4.78646202 6.94018468 2.83903981 4.85759175 5.69532129
#  6.29471312 4.29256215 5.98704707 5.82413826 5.68879146 5.47378749
#  7.28394618 5.54808326 5.42854557 5.82829728 4.41933524 3.90377785]
# actual price Country
# Serbia                  5.123
# Lebanon                 4.839
# Ivory Coast             3.655
# Switzerland             7.587
# Azerbaijan              5.212
# Algeria                 5.605
# Niger                   3.845
# Kyrgyzstan              5.286
# United Arab Emirates    6.901
# Taiwan                  6.298
# Israel                  7.278
# Georgia                 4.297
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('predicted result price:',pred)
print('actual price',y_test)
r=r2_score(y_test,pred)
print('r2score is',r)
# Out:
# predicted result price: [5.05549 5.08136 4.05862 7.32196 5.37161 5.73118 3.68091 5.60058 6.97271
#  6.13877 6.43377 4.58381 5.0789  5.06623 4.77755 7.38661 6.48134 4.63276
#  6.33983 6.97362 4.33546 4.93351 4.6567  4.17814 5.76138 4.50767 6.93759
#  6.17202 5.76187 4.53046 5.2787  4.82862 7.03519 3.60851 5.29003 5.90476
#  6.42607 4.20054 6.24751 5.76381 5.74324 6.43629 7.23706 5.14592 5.68112
#  5.97685 4.25345 4.10138]
# actual price Country
# Serbia                  5.123
# Lebanon                 4.839
# Ivory Coast             3.655
# Switzerland             7.587
# Azerbaijan              5.212
# Algeria                 5.605
# Niger                   3.845
# Kyrgyzstan              5.286
# United Arab Emirates    6.901
# Taiwan                  6.298
# Israel                  7.278
# Georgia                 4.297
# Dominican Republic      4.885
# Jordan                  5.192
# Bangladesh              4.694
# Denmark                 7.527
# Costa Rica              7.226
# ...

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(lm,x,y,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.9999981871007761

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(dt,x,y,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is -6.95141451690864

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(sr,x,y,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is 0.02870730560423258

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(rf,x,y,cv=5)
print('coss validation score is',scr.mean())
# Out:
# coss validation score is -3.1965548029466673

# %% [markdown]
# minimum difference in accuracy and cross validation score is for LinearRegression

# %% [markdown]
# ## saving the model

# %%
import joblib
joblib.dump(lm,'happiness.pkl')

# %%
happiness = joblib.load('happiness.pkl')

# %%
happiness.predict(x_train)

# %%
joblib.dump(lm,'lmmodel.obj')
